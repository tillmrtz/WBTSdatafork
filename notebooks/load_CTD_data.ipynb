# %% [markdown]
# ## Import all necessary packages

# %%
import numpy as np
import pandas as pd
import os
import xarray as xr
import datetime
import matplotlib.pyplot as plt

# %%
### Import the functions to load the calibration files and the 
import load_cal_files
import missing_datetime_2005_05 as mdt
# Out:
# /Users/tillmoritz/Desktop/Work/Git/WBTSdata/notebooks/load_cal_files.py:16: SyntaxWarning: invalid escape sequence '\s'
#   cal_list.append(pd.read_csv(os.path.join(cal_dir, cal_file), names=column_names, skiprows=12, sep='\s+'))

# %% [markdown]
# ### Define all directories of the calibration data

# %%
dir_01_04 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2001_04/CTD'
dir_02_06 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2002_06/CTD'
dir_03_02 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2003_02/CTD'
dir_04_09 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2004_09/CTD'
dir_05_05 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2005_05/CTD'
dir_05_09 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2005_09/CTD'
dir_06_03 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2006_03/CTD'
dir_06_09 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2006_09/CTD'
dir_07_03 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2007_03/CTD'
dir_07_09 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2007_09/CTD'
dir_08_04 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2008_04/CTD'
dir_08_09 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2008_09/CTD'
dir_09_04 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2009_04/CTD'
dir_09_11 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2009_11/CTD'
dir_10_03 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2010_03/CTD'
dir_11_04 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2011_04/CTD'
dir_12_02 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2012_02/CTD'
dir_12_09 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2012_09/CTD'
dir_13_02 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2013_02/CTD'
dir_14_03 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2014_03/CTD'
dir_15_02 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2015_02/CTD'
dir_15_10 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2015_10/CTD'
dir_16_02 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2016_02/CTD'
dir_17_05 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2017_05/CTD'
dir_18_02 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2018_02/CTD'
dir_18_11 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2018_11/CTD'
dir_19_12 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2019_12/CTD'
dir_21_02 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2021_02/CTD'
dir_23_02 = '/Users/tillmoritz/Desktop/Work/WBTSData/GC_2023_02/CTD'

# %%
dir_list = [dir_01_04, dir_02_06, dir_03_02, dir_04_09, dir_05_05, dir_05_09, dir_06_03, dir_06_09, dir_07_03, dir_07_09,
            dir_08_04, dir_08_09, dir_09_04, dir_09_11, dir_10_03, dir_11_04, dir_12_02, dir_12_09, dir_13_02, dir_14_03,
            dir_15_02, dir_15_10, dir_16_02, dir_17_05, dir_18_02, dir_18_11, dir_19_12, dir_21_02, dir_23_02]

# %% [markdown]
# ### load and safe the complete dataset and the individual dataset for each year

# %%
ds_all = load_cal_files.create_complete_Dataset(dir_list)
# Out:
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2001_04/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2002_06/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2003_02/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2004_09/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2005_05/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2005_09/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2006_03/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2006_09/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2007_03/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2007_09/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2008_04/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2008_09/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2009_04/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2009_11/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2010_03/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2011_04/CTD
# /Users/tillmoritz/Desktop/Work/WBTSData/GC_2012_02/CTD
# ...

# %%
safe_path = '/Users/tillmoritz/Desktop/Work/Created_files'

# %%
file_name = 'all_data'
#ds_all.to_netcdf(safe_path + '' + file_name)

# %%
ds_all
# Out:
# <xarray.Dataset> Size: 405MB
# Dimensions:      (Pres: 5828, Datetime: 1448)
# Coordinates:
#   * Pres         (Pres) float64 47kB 1.0 2.0 3.0 ... 5.827e+03 5.828e+03
#   * Datetime     (Datetime) datetime64[ns] 12kB 2001-04-26T17:06:00 ... 2023-...
#     Cast         (Datetime) float64 12kB 0.0 1.0 6.0 5.0 ... 19.0 20.0 21.0 22.0
#     Lat          (Datetime) float64 12kB 26.45 27.02 26.07 ... 26.49 26.49 26.49
#     Lon          (Datetime) float64 12kB -79.92 -79.92 -78.86 ... -72.75 -72.39
# Data variables:
#     Temp         (Pres, Datetime) float64 68MB 26.06 26.02 25.69 ... nan nan nan
#     Pot. Temp    (Pres, Datetime) float64 68MB 26.06 26.02 25.69 ... nan nan nan
#     PSAL         (Pres, Datetime) float64 68MB 36.21 36.23 36.19 ... nan nan nan
#     Dyn. Height  (Pres, Datetime) float64 68MB 0.004 0.004 0.004 ... nan nan nan
#     ga           (Pres, Datetime) float64 68MB 0.993 0.993 0.993 ... nan nan nan
# ...

# %%
### plot the data with inverted axis
plt.figure(figsize=(15,10))
ds_all.plot.scatter(x='Datetime', y='PRES', hue='TEMP', s=20, cmap='viridis', edgecolor='face')
plt.gca().invert_yaxis()
plt.show()
